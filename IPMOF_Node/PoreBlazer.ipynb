# %%
import os
from IPMOFresults import *
import matplotlib.pyplot as plt

# %%
psdDir = r'C:\Kutay\IPMOF_MOF5\PB'

# %%
PBres = PB.readResults(psdDir)

# %%
PSD = PB.PSD(psdDir)

# %%
# %pylab inline
PB.plotPSD(PSD)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
PSD['DPD']
# Out:
# 5.625

# %%
sourceDir = r'C:\Kutay\poreblazer_v3.0.2_d\Source'
exportDir = r'C:\Kutay\IPMOF_MOF5\PB_Python'

# %%
PB.initialize(sourceDir, exportDir)

# %%
MOFname = 'MOF5'
UCsize = [26, 26, 26]
UCangle = [90, 90, 90]
PB.input(MOFname, UCsize, UCangle, exportDir)
