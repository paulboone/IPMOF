# %% [markdown]
# ## Initialize Input Files for IPMOF (initialize_IPMOF.py)
#
# ### Initialize necessary information
#
# 1. Read FF_Parameters excel file to get force field parameters for atoms
# 2. Initialize force field selection, cutOff radius and grid size for energy map
#
# ### Create input files for MOF files in a given directory
# 1. Reaf MOF files in ".mol2" format from given directory and create a list
# 2. Choose the first MOF1 as the stationary (map) MOF, initialize its variables, and calculate packed coordinates
# 3. For all the MOFs in the list:
# 4. Initialize MOF2 variables for the mobile MOF
# 5. Calculate energy map
# 6. Export energy map -> .json
# 7. Export MOF2 structure information -> .json

# %%
import math
import os
os.chdir('C:\\Kutay\\IPMOF')
from energyMapFunctions import *

# Read excel file containing force field information
excelFileDir = 'C:\\Users\\kutay\\iPython\\IPMOF\\FF_Parameters.xlsx'
UFF = readFFparameters(excelFileDir, 'UFF')

# Read radius list from the excel file
radiusList = readAtomRadius()

# Generate MOF list
fileDir = 'C:\\Users\kutay\\Desktop\\REFmol2'
fileFormat = ".mol2"
MOFlist = generateMOFlist(fileDir, fileFormat)
MOFnames = []

#cutOff = 13
orthoCount = 0
VFtotal = 0
MOFs = []
for MOFindex, mof in enumerate(MOFlist):
    newMOF = MOF()
    newMOF.dir = fileDir + '\\' + mof
    newMOF.file = open(newMOF.dir, 'r')
    newMOF.initialize()
    
    # Calculate void fraction
    atomVolumes = atomicVolume(newMOF, radiusList)
    UnitCellVolume = ucv(newMOF)
    newMOF.UCV = UnitCellVolume
    newMOF.atomDensity = atomVolumes / UnitCellVolume
    newMOF.voidFraction = 1 - atomVolumes / UnitCellVolume
 
    # Calculate packing for base MOF
    widthA = newMOF.UCV / (newMOF.UCsize[1]*newMOF.UCsize[2] / math.sin(math.radians(newMOF.UCangle[0])))
    widthB = newMOF.UCV / (newMOF.UCsize[0]*newMOF.UCsize[2] / math.sin(math.radians(newMOF.UCangle[1])))
    widthC = newMOF.UCV / (newMOF.UCsize[0]*newMOF.UCsize[1] / math.sin(math.radians(newMOF.UCangle[2])))
    newMOF.cutOff = min(widthA/2, widthB/2, widthC/2)
    packingFactor = Packing.factor(newMOF.UCsize, newMOF.cutOff)
    newMOF.packingFactor = packingFactor
    translationVectors, UCvectors = Packing.vectors(packingFactor, newMOF.UCsize, newMOF.UCangle)
    newMOF.packedCoor = Packing.UC(translationVectors, packingFactor, UCvectors, newMOF.atomCoor)
    newMOF.edgePoints = Packing.edgePoints(UCvectors)
    
    if newMOF.voidFraction > 0.94:
        MOFname = MOFlist[MOFindex].split('.')[0]
        MOFname = MOFname.split('_')[0]
        newMOF.name = MOFname
        MOFs.append(newMOF)
        VFtotal += newMOF.voidFraction
        orthoCount += 1 

VFaverage = VFtotal / orthoCount
    
print('Vf > 0.94 MOF count: ' + str(orthoCount))
print('Average Void Fraction: ' +str(VFaverage))
# Out:
# Vf > 0.94 MOF count: 60
# Average Void Fraction: 0.9492591508735512

# %%
targetVF = 0.94
refinedMOFs = []
refinedCount = 0
table = []
identicalMOFs = []
counterpartMOFs = []
for mofIndex, mof in enumerate(MOFs):
    if mof.voidFraction > targetVF:
        mof.initializeFF(UFF)
        #foundIdentical = False
        if mofIndex > 0:
            for refMOF in refinedMOFs:
                if round(mof.voidFraction, 2) == round(refMOF.voidFraction, 2):
                    if sorted(refMOF.uniqueAtomNames) == sorted(mof.uniqueAtomNames):
                        #if not foundIdentical:
                            identicalMOFs.append(mof)
                            counterpartMOFs.append(refMOF.name)
                            #foundIdentical = True
        refinedMOFs.append(mof)
        table.append([])
        table[refinedCount].append(mof.name)
        table[refinedCount].append(mof.uniqueAtomNames)
        table[refinedCount].append(mof.UCsize)
        table[refinedCount].append(mof.UCangle)
        table[refinedCount].append(round(mof.voidFraction, 2))
        table[refinedCount].append(round(mof.cutOff, 2))
        #table[refinedCount].append(mof.packingFactor)
        refinedCount += 1
#del MOFs
        
from tabulate import tabulate

headers = ["MOF Name", "Atoms", "UCsize", "UCangle", "VF", "Cut-Off"]
print(tabulate(table, headers))
# Out:
# MOF Name      Atoms                             UCsize                       UCangle                          VF    Cut-Off
# ------------  --------------------------------  ---------------------------  -----------------------------  ----  ---------
# ALAMUW        ['H', 'C', 'N', 'O', 'Cu']        [18.794, 18.794, 19.9351]    [61.8761, 61.8761, 60.0]       0.96       6.02
# ANOMUM        ['O', 'Cu', 'H', 'C', 'N']        [10.3036, 15.2248, 20.4069]  [111.9026, 104.6228, 90.0]     0.96       4.27
# BAKJII        ['H', 'O', 'Co', 'C', 'N']        [11.85, 13.853, 13.944]      [90.0, 114.793, 90.0]          0.94       5.38
# BEPRIZ        ['H', 'C', 'O', 'Co', 'N']        [18.9, 18.9, 18.9]           [61.8682, 61.8682, 61.8682]    0.94       6.14
# BICDAU        ['H', 'C', 'N', 'Zn']             [17.75, 17.75, 19.192]       [90.0, 90.0, 120.0]            0.95       7.2
# BIFKEI        ['H', 'C', 'N', 'Cu', 'Cl', 'O']  [12.287, 12.916, 18.199]     [86.733, 70.443, 80.146]       0.94       5.65
# BUKMUQ        ['H', 'C', 'O', 'Zn', 'N']        [10.4465, 11.7859, 14.6048]  [90.0, 90.0, 90.0]             0.94       5.22
# CEKHIL        ['H', 'C', 'O', 'Co', 'N']        [10.152, 17.953, 18.062]     [90.0, 94.62, 90.0]            0.95       5.06
# COF-300       ['H', 'C', 'N']                   [8.879, 20.3783, 20.3783]    [87.2797, 77.4169, 77.4169]    0.96       4.22
# COF-5         ['C', 'B', 'H', 'O']              [3.404, 30.0198, 30.0198]    [120.0, 90.0, 90.0]            0.97       1.28
# COGWEB        ['C', 'O', 'Zn', 'H', 'N']        [12.935, 12.935, 23.242]     [90.0, 90.0, 90.0]             0.94       6.47
# CUYWUP        ['H', 'O', 'C', 'Cu']             [10.6753, 17.844, 27.353]    [90.0, 90.0, 90.0]             0.95       5.34
# DEPXIG        ['Mn', 'O', 'H', 'C', 'N']        [11.849, 17.711, 18.903]     [114.86, 90.0, 90.0]           0.94       4.88
# DEYVUA        ['O', 'Zn', 'H', 'C', 'N']        [13.4641, 13.4641, 23.3751]  [90.0, 90.0, 90.0]             0.95       6.73
# EDOMAM        ['O', 'Cu', 'H', 'C', 'N']        [13.941, 15.075, 15.075]     [82.15, 87.23, 87.23]          0.96       6.83
# FAYKOH        ['H', 'C', 'O', 'In']             [16.5388, 17.6725, 17.6725]  [77.3525, 62.1004, 62.1004]    0.95       6.1
# FEWTUY        ['Ni', 'H', 'C', 'O', 'N']        [12.8538, 19.8687, 19.8687]  [77.765, 72.4993, 72.499]      0.94       5.66
# FUNBOG        ['H', 'C', 'Br', 'O', 'Zn', 'N']  [11.711, 15.6181, 16.0362]   [90.0, 90.205, 90.0]           0.96       5.86
# FUTKEL        ['Zn', 'O', 'H', 'C', 'N']        [15.2904, 15.2904, 17.6674]  [115.6404, 115.6404, 90.0001]  0.95       5.45
# GALBUS        ['H', 'N', 'C', 'O', 'Ni']        [12.7222, 22.3163, 22.3163]  [90.0, 90.0, 90.0]             0.94       6.36
# GINLIA        ['H', 'C', 'O', 'Zn', 'Cl']       [10.1889, 16.651, 19.73]     [90.0, 101.825, 90.0]          0.94       4.99
# GIYTIS        ['Zn', 'H', 'C', 'O', 'N']        [8.9508, 9.0892, 19.802]     [95.64, 97.68, 118.25]         0.94       3.82
# GUNFAW01      ['C', 'O', 'Cr', 'Mn']            [15.4901, 15.4901, 15.4901]  [90.0, 90.0, 90.0]             0.95       7.75
# HEGJUZ        ['O', 'Zn', 'H', 'C', 'N']        [14.608, 18.041, 24.803]     [90.0, 90.005, 90.0]           0.95       7.3
# HIGRIA        ['H', 'C', 'N', 'Zn', 'Co']       [17.7771, 17.7771, 19.1129]  [90.0, 90.0, 120.0]            0.95       7.17
# HIHNUJ        ['H', 'C', 'O', 'In']             [11.2184, 17.9218, 17.9218]  [90.0, 90.0, 90.0]             0.95       5.61
# IRMOF-7       ['H', 'C', 'O', 'Zn']             [12.9144, 12.9144, 12.9144]  [90.0, 90.0, 90.0]             0.95       6.46
# IXAJUN        ['Cu', 'O', 'H', 'C', 'N']        [11.9132, 13.546, 13.67]     [90.0, 113.959, 90.0]          0.94       5.44
# IXAKAU        ['Cu', 'O', 'H', 'C', 'N']        [14.207, 14.564, 26.22]      [90.0, 90.0, 107.08]           0.95       6.79
# IYIHUU        ['Zn', 'O', 'H', 'C', 'Br', 'N']  [11.106, 15.916, 16.224]     [90.0, 101.594, 90.0]          0.96       5.44
# JEJWOL        ['Nd', 'O', 'H', 'C', 'N']        [15.156, 15.657, 26.967]     [81.603, 78.042, 73.529]       0.94       7
# LUVTEC        ['H', 'O', 'Zn', 'C', 'N']        [15.133, 17.6776, 17.6776]   [90.0, 90.0, 90.0]             0.94       7.57
# LUYHAP        ['H', 'C', 'O', 'Cu']             [17.5311, 17.5311, 17.5311]  [62.6884, 62.6884, 62.6884]    0.96       5.84
# MATVAF        ['C', 'O', 'Zn', 'H', 'N']        [12.9938, 13.0908, 22.318]   [90.0, 90.0, 102.582]          0.94       6.34
# MATVEJ        ['H', 'O', 'Zn', 'C', 'N']        [15.1644, 15.1729, 22.273]   [82.987, 78.446, 72.771]       0.96       6.94
# MICNIW        ['C', 'F', 'H', 'N', 'Cd']        [12.8267, 12.8267, 16.69]    [108.682, 108.682, 95.9725]    0.94       5.31
# MICNUI        ['C', 'F', 'H', 'N', 'Cd']        [13.0366, 13.0366, 16.24]    [109.539, 109.539, 95.4748]    0.94       5.31
# MICPAQ        ['C', 'F', 'H', 'N', 'Cd']        [13.047, 13.279, 16.6145]    [111.121, 109.442, 92.734]     0.94       5.25
# MIL-88C-open  ['H', 'C', 'O', 'Fe']             [18.7425, 18.7529, 18.7529]  [120.0, 90.0, 90.0]            0.96       7.03
# MOCKEV        ['H', 'C', 'N', 'O', 'Cu']        [14.8966, 14.8966, 14.8966]  [78.2453, 78.2453, 78.2453]    0.95       6.89
# MUZHUL        ['O', 'H', 'C', 'Zn']             [7.3562, 7.3562, 16.3]       [90.7568, 90.7568, 95.9011]    0.94       3.66
# NAQLAT        ['O', 'Zn', 'H', 'C', 'N']        [12.5583, 14.5949, 25.741]   [100.093, 90.0, 90.0]          0.94       6.09
# NEDWIE        ['H', 'C', 'O', 'Mn', 'Ni']       [15.6802, 16.6187, 16.8631]  [98.782, 109.215, 114.858]     0.94       6.17
# NEHNEV        ['O', 'Zn', 'H', 'C', 'N']        [10.6549, 14.5638, 16.0435]  [99.783, 102.396, 101.834]     0.94       4.89
# OFODAP        ['O', 'Cd', 'H', 'C', 'N']        [12.8597, 15.1207, 23.516]   [90.0, 90.0, 90.0]             0.95       6.43
# PEVQIS        ['H', 'C', 'O', 'Zn']             [18.1401, 18.1401, 18.1401]  [60.0, 60.0, 60.0]             0.96       5.55
# PEVQOY        ['H', 'C', 'O', 'Zn']             [18.0616, 18.0616, 18.0616]  [60.0, 60.0, 60.0]             0.96       5.53
# QUQFIS        ['H', 'C', 'O', 'Zn']             [18.59, 18.59, 18.59]        [74.8765, 74.8765, 74.8765]    0.94       8.18
# RAVWAO        ['H', 'C', 'O', 'Mg']             [6.4739, 26.5533, 26.5533]   [119.3467, 94.6615, 94.6615]   0.95       2.43
# RAXCOK        ['H', 'C', 'O', 'Zn', 'N', 'S']   [16.644, 17.615, 19.66]      [91.89, 90.0, 90.0]            0.95       8.31
# TONQOD        ['H', 'C', 'O', 'Zn']             [9.2945, 19.4305, 19.4305]   [67.7291, 76.1623, 76.1624]    0.95       3.81
# UNIGEE        ['H', 'C', 'O', 'Zn']             [18.1424, 18.1424, 18.1424]  [60.0, 60.0, 60.0]             0.96       5.55
# VUSJUP        ['C', 'O', 'Zn', 'H']             [18.101, 18.101, 18.101]     [60.0036, 60.0036, 60.0001]    0.95       5.54
# XAWVUN        ['H', 'C', 'N', 'O', 'Cu']        [15.2563, 16.0699, 23.5937]  [90.0, 90.0, 118.3388]         0.96       6.71
# XEBHOC        ['H', 'C', 'N', 'O', 'Cu']        [15.376, 19.8482, 19.8482]   [73.3583, 67.2109, 67.2109]    0.97       6.18
# XINFUW        ['H', 'C', 'O', 'Zn']             [12.6977, 15.1033, 18.903]   [90.0, 90.0, 90.0]             0.94       6.35
# XUGSEY        ['H', 'Zn', 'O', 'C', 'N', 'F']   [11.569, 15.447, 21.19]      [76.794, 79.025, 89.615]       0.95       5.38
# YURJUR        ['H', 'C', 'O', 'Ce', 'S']        [17.5757, 17.5757, 17.5757]  [90.9296, 90.9296, 90.9296]    0.94       8.78
# ZIKJIO        ['Cu', 'O', 'H', 'C', 'N']        [11.4269, 11.4269, 18.8731]  [94.7584, 94.7584, 96.7219]    0.96       5.61
# ZIKJOU        ['Cu', 'O', 'H', 'C', 'N']        [10.6325, 10.7258, 18.3532]  [76.671, 86.717, 74.278]       0.95       4.85

# %%
for mof, cmof in zip(identicalMOFs, counterpartMOFs):
    print(mof.name +'\t' + cmof)

print('-----------------------------------------------------')
print('Refined MOFs: ' + str(len(refinedMOFs)) + ' Identical MOFs: ' + str(len(identicalMOFs)))
print('Non-identical MOFs: ' + str(len(refinedMOFs) - len(identicalMOFs)))

nonidenticalMOFs = []
discardMOFs = []

   
for refMOF in refinedMOFs:
    if refMOF.name not in list(counterpartMOFs):
        nonidenticalMOFs.append(refMOF)

print('-----------')
print('Non-identical MOF count: ' + str(len(nonidenticalMOFs)))
for nonMOF in nonidenticalMOFs:
    print(nonMOF.name)
    
refinedMOFs = []
refinedMOFs = nonidenticalMOFs
# Out:
# ANOMUM	ALAMUW
# BEPRIZ	BAKJII
# COGWEB	BUKMUQ
# EDOMAM	ALAMUW
# EDOMAM	ANOMUM
# FUTKEL	DEYVUA
# GALBUS	FEWTUY
# GIYTIS	BUKMUQ
# GIYTIS	COGWEB
# HEGJUZ	DEYVUA
# HEGJUZ	FUTKEL
# HIHNUJ	FAYKOH
# IYIHUU	FUNBOG
# LUVTEC	BUKMUQ
# LUVTEC	COGWEB
# LUVTEC	GIYTIS
# MATVAF	BUKMUQ
# MATVAF	COGWEB
# MATVAF	GIYTIS
# MATVAF	LUVTEC
# MICNUI	MICNIW
# MICPAQ	MICNIW
# MICPAQ	MICNUI
# MOCKEV	IXAKAU
# NAQLAT	BUKMUQ
# NAQLAT	COGWEB
# NAQLAT	GIYTIS
# NAQLAT	LUVTEC
# NAQLAT	MATVAF
# NEHNEV	BUKMUQ
# NEHNEV	COGWEB
# NEHNEV	GIYTIS
# NEHNEV	LUVTEC
# NEHNEV	MATVAF
# NEHNEV	NAQLAT
# PEVQOY	PEVQIS
# QUQFIS	MUZHUL
# TONQOD	IRMOF-7
# UNIGEE	PEVQIS
# UNIGEE	PEVQOY
# VUSJUP	IRMOF-7
# VUSJUP	TONQOD
# XAWVUN	ALAMUW
# XAWVUN	ANOMUM
# XAWVUN	EDOMAM
# XINFUW	MUZHUL
# XINFUW	QUQFIS
# ZIKJIO	ALAMUW
# ZIKJIO	ANOMUM
# ZIKJIO	EDOMAM
# ZIKJIO	XAWVUN
# ZIKJOU	IXAKAU
# ZIKJOU	MOCKEV
# -----------------------------------------------------
# Refined MOFs: 60 Identical MOFs: 53
# Non-identical MOFs: 7
# -----------
# Non-identical MOF count: 34
# BEPRIZ
# BICDAU
# BIFKEI
# CEKHIL
# COF-300
# COF-5
# CUYWUP
# DEPXIG
# GALBUS
# GINLIA
# GUNFAW01
# HEGJUZ
# HIGRIA
# HIHNUJ
# IXAJUN
# IYIHUU
# JEJWOL
# LUYHAP
# MATVEJ
# MICPAQ
# MIL-88C-open
# NEDWIE
# NEHNEV
# OFODAP
# RAVWAO
# RAXCOK
# UNIGEE
# VUSJUP
# XEBHOC
# XINFUW
# XUGSEY
# YURJUR
# ZIKJIO
# ZIKJOU

# %%
# Creates atom list for non-repeating atoms from a list of MOF classes
atomList = getUniqueAtomList(refinedMOFs)

# Creates atom list required in the energy map of a combination of MOFs
eMapAtomList = getEnergyMapAtomList(refinedMOFs, atomList)

# Directory and format to export energy map and MOF structure files
exportFolder = "C:\\Kutay\\IPMOF_Input"
exportFormat = ".js"

for MOFindex, mof in enumerate(refinedMOFs):  
           
    # Create export directory for the base MOF and create folder
    exportMOFfolder = os.path.join(exportFolder, mof.name)
    os.mkdir(exportMOFfolder)
    
    # --------------------- Calculate Energy Map -------------------
    # For each MOF energy map is calculated with an atom list that consists of all the unique atoms z
    # for a given list of MOFs
    eMap = energyMap(mof, atomList, mof.cutOff, 1)
    
    avgEnergyLimits = calculateEnergyLimits(MOFindex, refinedMOFs, MOFlist, eMapAtomList, eMap)
    
    for MOFindex2, mof2 in enumerate(refinedMOFs):
        
        if MOFindex2 >= MOFindex:        
            # Create export directory for the mobile MOF and create folder
            exportMOFfolder2 = os.path.join(exportMOFfolder, mof2.name)
            os.mkdir(exportMOFfolder2)

            # Create export directory for mobile MOF
            exportDir_MOF = os.path.join(exportMOFfolder2, mof2.name + exportFormat)
            exportGLOBALMOFjs(mof2, exportDir_MOF)
            print(exportDir_MOF.split("\\")[-1] + ' is exported')

            # Create export directory for energy map
            exportDir_eMap = os.path.join(exportMOFfolder2, mof.name + '+' + mof2.name + '_eMap' + exportFormat)
            exportGLOBALEnergyMapjs(eMap, avgEnergyLimits[MOFindex2], eMapAtomList, MOFindex2, exportDir_eMap)
            print(exportDir_eMap.split("\\")[-1] + ' is exported')

            # Export base MOF structure
            exportDir_baseMOF = os.path.join(exportMOFfolder2, 'base' + mof.name + exportFormat)
            exportGLOBALBaseMOFjs(refinedMOFs[MOFindex], exportDir_baseMOF)
            print(exportDir_baseMOF.split("\\")[-1] + ' is exported')
# Out:
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   4.05117e+12
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        4.90008e+12
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             6.95879e+12
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   4.05117e+12
# ABEXUC_clean    ['H', 'C', 'N']                              6.07695e+12
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         4.90008e+12
# ABEYIR          ['O', 'H', 'C', 'Cu']                        4.90008e+12
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   4.05117e+12
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   4.05117e+12
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  4.05117e+12
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       4.90008e+12
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   4.05117e+12
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  4.05117e+12
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        4.90008e+12
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   4.05117e+12
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             6.95879e+12
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   4.05117e+12
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        4.90008e+12
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   4.05117e+12
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   4.05117e+12
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        4.90008e+12
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  4.05117e+12
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   4.05117e+12
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   4.05117e+12
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        4.90008e+12
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              6.95879e+12
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        4.90008e+12
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        4.90008e+12
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   4.05117e+12
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        4.90008e+12
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              6.95879e+12
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   4.05117e+12
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   4.05117e+12
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   4.05117e+12
# BEPRIZ.js is exported
# BEPRIZ+BEPRIZ_eMap.js is exported
# baseBEPRIZ.js is exported
# BICDAU.js is exported
# BEPRIZ+BICDAU_eMap.js is exported
# baseBEPRIZ.js is exported
# BIFKEI.js is exported
# BEPRIZ+BIFKEI_eMap.js is exported
# baseBEPRIZ.js is exported
# CEKHIL.js is exported
# BEPRIZ+CEKHIL_eMap.js is exported
# baseBEPRIZ.js is exported
# COF-300.js is exported
# BEPRIZ+COF-300_eMap.js is exported
# baseBEPRIZ.js is exported
# COF-5.js is exported
# BEPRIZ+COF-5_eMap.js is exported
# baseBEPRIZ.js is exported
# CUYWUP.js is exported
# BEPRIZ+CUYWUP_eMap.js is exported
# baseBEPRIZ.js is exported
# DEPXIG.js is exported
# BEPRIZ+DEPXIG_eMap.js is exported
# baseBEPRIZ.js is exported
# GALBUS.js is exported
# BEPRIZ+GALBUS_eMap.js is exported
# baseBEPRIZ.js is exported
# GINLIA.js is exported
# BEPRIZ+GINLIA_eMap.js is exported
# baseBEPRIZ.js is exported
# GUNFAW01.js is exported
# BEPRIZ+GUNFAW01_eMap.js is exported
# baseBEPRIZ.js is exported
# HEGJUZ.js is exported
# BEPRIZ+HEGJUZ_eMap.js is exported
# baseBEPRIZ.js is exported
# HIGRIA.js is exported
# BEPRIZ+HIGRIA_eMap.js is exported
# baseBEPRIZ.js is exported
# HIHNUJ.js is exported
# BEPRIZ+HIHNUJ_eMap.js is exported
# baseBEPRIZ.js is exported
# IXAJUN.js is exported
# BEPRIZ+IXAJUN_eMap.js is exported
# baseBEPRIZ.js is exported
# IYIHUU.js is exported
# BEPRIZ+IYIHUU_eMap.js is exported
# baseBEPRIZ.js is exported
# JEJWOL.js is exported
# BEPRIZ+JEJWOL_eMap.js is exported
# baseBEPRIZ.js is exported
# LUYHAP.js is exported
# BEPRIZ+LUYHAP_eMap.js is exported
# baseBEPRIZ.js is exported
# MATVEJ.js is exported
# BEPRIZ+MATVEJ_eMap.js is exported
# baseBEPRIZ.js is exported
# MICPAQ.js is exported
# BEPRIZ+MICPAQ_eMap.js is exported
# baseBEPRIZ.js is exported
# MIL-88C-open.js is exported
# BEPRIZ+MIL-88C-open_eMap.js is exported
# baseBEPRIZ.js is exported
# NEDWIE.js is exported
# BEPRIZ+NEDWIE_eMap.js is exported
# baseBEPRIZ.js is exported
# NEHNEV.js is exported
# BEPRIZ+NEHNEV_eMap.js is exported
# baseBEPRIZ.js is exported
# OFODAP.js is exported
# BEPRIZ+OFODAP_eMap.js is exported
# baseBEPRIZ.js is exported
# RAVWAO.js is exported
# BEPRIZ+RAVWAO_eMap.js is exported
# baseBEPRIZ.js is exported
# RAXCOK.js is exported
# BEPRIZ+RAXCOK_eMap.js is exported
# baseBEPRIZ.js is exported
# UNIGEE.js is exported
# BEPRIZ+UNIGEE_eMap.js is exported
# baseBEPRIZ.js is exported
# VUSJUP.js is exported
# BEPRIZ+VUSJUP_eMap.js is exported
# baseBEPRIZ.js is exported
# XEBHOC.js is exported
# BEPRIZ+XEBHOC_eMap.js is exported
# baseBEPRIZ.js is exported
# XINFUW.js is exported
# BEPRIZ+XINFUW_eMap.js is exported
# baseBEPRIZ.js is exported
# XUGSEY.js is exported
# BEPRIZ+XUGSEY_eMap.js is exported
# baseBEPRIZ.js is exported
# YURJUR.js is exported
# BEPRIZ+YURJUR_eMap.js is exported
# baseBEPRIZ.js is exported
# ZIKJIO.js is exported
# BEPRIZ+ZIKJIO_eMap.js is exported
# baseBEPRIZ.js is exported
# ZIKJOU.js is exported
# BEPRIZ+ZIKJOU_eMap.js is exported
# baseBEPRIZ.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   7.14595e+11
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        8.66512e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             1.25406e+12
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   7.14595e+11
# ABEXUC_clean    ['H', 'C', 'N']                              1.07864e+12
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         8.66512e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        8.66512e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   7.14595e+11
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   7.14595e+11
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  7.14595e+11
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       8.66512e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   7.14595e+11
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  7.14595e+11
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        8.66512e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.14595e+11
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             1.25406e+12
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   7.14595e+11
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        8.66512e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   7.14595e+11
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   7.14595e+11
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        8.66512e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  7.14595e+11
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   7.14595e+11
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   7.14595e+11
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        8.66512e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              1.25406e+12
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        8.66512e+11
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        8.66512e+11
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.14595e+11
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        8.66512e+11
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              1.25406e+12
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   7.14595e+11
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.14595e+11
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.14595e+11
# BICDAU.js is exported
# BICDAU+BICDAU_eMap.js is exported
# baseBICDAU.js is exported
# BIFKEI.js is exported
# BICDAU+BIFKEI_eMap.js is exported
# baseBICDAU.js is exported
# CEKHIL.js is exported
# BICDAU+CEKHIL_eMap.js is exported
# baseBICDAU.js is exported
# COF-300.js is exported
# BICDAU+COF-300_eMap.js is exported
# baseBICDAU.js is exported
# COF-5.js is exported
# BICDAU+COF-5_eMap.js is exported
# baseBICDAU.js is exported
# CUYWUP.js is exported
# BICDAU+CUYWUP_eMap.js is exported
# baseBICDAU.js is exported
# DEPXIG.js is exported
# BICDAU+DEPXIG_eMap.js is exported
# baseBICDAU.js is exported
# GALBUS.js is exported
# BICDAU+GALBUS_eMap.js is exported
# baseBICDAU.js is exported
# GINLIA.js is exported
# BICDAU+GINLIA_eMap.js is exported
# baseBICDAU.js is exported
# GUNFAW01.js is exported
# BICDAU+GUNFAW01_eMap.js is exported
# baseBICDAU.js is exported
# HEGJUZ.js is exported
# BICDAU+HEGJUZ_eMap.js is exported
# baseBICDAU.js is exported
# HIGRIA.js is exported
# BICDAU+HIGRIA_eMap.js is exported
# baseBICDAU.js is exported
# HIHNUJ.js is exported
# BICDAU+HIHNUJ_eMap.js is exported
# baseBICDAU.js is exported
# IXAJUN.js is exported
# BICDAU+IXAJUN_eMap.js is exported
# baseBICDAU.js is exported
# IYIHUU.js is exported
# BICDAU+IYIHUU_eMap.js is exported
# baseBICDAU.js is exported
# JEJWOL.js is exported
# BICDAU+JEJWOL_eMap.js is exported
# baseBICDAU.js is exported
# LUYHAP.js is exported
# BICDAU+LUYHAP_eMap.js is exported
# baseBICDAU.js is exported
# MATVEJ.js is exported
# BICDAU+MATVEJ_eMap.js is exported
# baseBICDAU.js is exported
# MICPAQ.js is exported
# BICDAU+MICPAQ_eMap.js is exported
# baseBICDAU.js is exported
# MIL-88C-open.js is exported
# BICDAU+MIL-88C-open_eMap.js is exported
# baseBICDAU.js is exported
# NEDWIE.js is exported
# BICDAU+NEDWIE_eMap.js is exported
# baseBICDAU.js is exported
# NEHNEV.js is exported
# BICDAU+NEHNEV_eMap.js is exported
# baseBICDAU.js is exported
# OFODAP.js is exported
# BICDAU+OFODAP_eMap.js is exported
# baseBICDAU.js is exported
# RAVWAO.js is exported
# BICDAU+RAVWAO_eMap.js is exported
# baseBICDAU.js is exported
# RAXCOK.js is exported
# BICDAU+RAXCOK_eMap.js is exported
# baseBICDAU.js is exported
# UNIGEE.js is exported
# BICDAU+UNIGEE_eMap.js is exported
# baseBICDAU.js is exported
# VUSJUP.js is exported
# BICDAU+VUSJUP_eMap.js is exported
# baseBICDAU.js is exported
# XEBHOC.js is exported
# BICDAU+XEBHOC_eMap.js is exported
# baseBICDAU.js is exported
# XINFUW.js is exported
# BICDAU+XINFUW_eMap.js is exported
# baseBICDAU.js is exported
# XUGSEY.js is exported
# BICDAU+XUGSEY_eMap.js is exported
# baseBICDAU.js is exported
# YURJUR.js is exported
# BICDAU+YURJUR_eMap.js is exported
# baseBICDAU.js is exported
# ZIKJIO.js is exported
# BICDAU+ZIKJIO_eMap.js is exported
# baseBICDAU.js is exported
# ZIKJOU.js is exported
# BICDAU+ZIKJOU_eMap.js is exported
# baseBICDAU.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   1.74877e+12
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        2.116e+12
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             3.00447e+12
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   1.74877e+12
# ABEXUC_clean    ['H', 'C', 'N']                              2.62884e+12
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         2.116e+12
# ABEYIR          ['O', 'H', 'C', 'Cu']                        2.116e+12
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   1.74877e+12
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   1.74877e+12
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  1.74877e+12
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       2.116e+12
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   1.74877e+12
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  1.74877e+12
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        2.116e+12
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.74877e+12
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             3.00447e+12
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   1.74877e+12
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        2.116e+12
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.74877e+12
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   1.74877e+12
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        2.116e+12
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  1.74877e+12
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.74877e+12
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   1.74877e+12
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        2.116e+12
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              3.00447e+12
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        2.116e+12
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        2.116e+12
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.74877e+12
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        2.116e+12
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              3.00447e+12
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   1.74877e+12
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.74877e+12
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.74877e+12
# BIFKEI.js is exported
# BIFKEI+BIFKEI_eMap.js is exported
# baseBIFKEI.js is exported
# CEKHIL.js is exported
# BIFKEI+CEKHIL_eMap.js is exported
# baseBIFKEI.js is exported
# COF-300.js is exported
# BIFKEI+COF-300_eMap.js is exported
# baseBIFKEI.js is exported
# COF-5.js is exported
# BIFKEI+COF-5_eMap.js is exported
# baseBIFKEI.js is exported
# CUYWUP.js is exported
# BIFKEI+CUYWUP_eMap.js is exported
# baseBIFKEI.js is exported
# DEPXIG.js is exported
# BIFKEI+DEPXIG_eMap.js is exported
# baseBIFKEI.js is exported
# GALBUS.js is exported
# BIFKEI+GALBUS_eMap.js is exported
# baseBIFKEI.js is exported
# GINLIA.js is exported
# BIFKEI+GINLIA_eMap.js is exported
# baseBIFKEI.js is exported
# GUNFAW01.js is exported
# BIFKEI+GUNFAW01_eMap.js is exported
# baseBIFKEI.js is exported
# HEGJUZ.js is exported
# BIFKEI+HEGJUZ_eMap.js is exported
# baseBIFKEI.js is exported
# HIGRIA.js is exported
# BIFKEI+HIGRIA_eMap.js is exported
# baseBIFKEI.js is exported
# HIHNUJ.js is exported
# BIFKEI+HIHNUJ_eMap.js is exported
# baseBIFKEI.js is exported
# IXAJUN.js is exported
# BIFKEI+IXAJUN_eMap.js is exported
# baseBIFKEI.js is exported
# IYIHUU.js is exported
# BIFKEI+IYIHUU_eMap.js is exported
# baseBIFKEI.js is exported
# JEJWOL.js is exported
# BIFKEI+JEJWOL_eMap.js is exported
# baseBIFKEI.js is exported
# LUYHAP.js is exported
# BIFKEI+LUYHAP_eMap.js is exported
# baseBIFKEI.js is exported
# MATVEJ.js is exported
# BIFKEI+MATVEJ_eMap.js is exported
# baseBIFKEI.js is exported
# MICPAQ.js is exported
# BIFKEI+MICPAQ_eMap.js is exported
# baseBIFKEI.js is exported
# MIL-88C-open.js is exported
# BIFKEI+MIL-88C-open_eMap.js is exported
# baseBIFKEI.js is exported
# NEDWIE.js is exported
# BIFKEI+NEDWIE_eMap.js is exported
# baseBIFKEI.js is exported
# NEHNEV.js is exported
# BIFKEI+NEHNEV_eMap.js is exported
# baseBIFKEI.js is exported
# OFODAP.js is exported
# BIFKEI+OFODAP_eMap.js is exported
# baseBIFKEI.js is exported
# RAVWAO.js is exported
# BIFKEI+RAVWAO_eMap.js is exported
# baseBIFKEI.js is exported
# RAXCOK.js is exported
# BIFKEI+RAXCOK_eMap.js is exported
# baseBIFKEI.js is exported
# UNIGEE.js is exported
# BIFKEI+UNIGEE_eMap.js is exported
# baseBIFKEI.js is exported
# VUSJUP.js is exported
# BIFKEI+VUSJUP_eMap.js is exported
# baseBIFKEI.js is exported
# XEBHOC.js is exported
# BIFKEI+XEBHOC_eMap.js is exported
# baseBIFKEI.js is exported
# XINFUW.js is exported
# BIFKEI+XINFUW_eMap.js is exported
# baseBIFKEI.js is exported
# XUGSEY.js is exported
# BIFKEI+XUGSEY_eMap.js is exported
# baseBIFKEI.js is exported
# YURJUR.js is exported
# BIFKEI+YURJUR_eMap.js is exported
# baseBIFKEI.js is exported
# ZIKJIO.js is exported
# BIFKEI+ZIKJIO_eMap.js is exported
# baseBIFKEI.js is exported
# ZIKJOU.js is exported
# BIFKEI+ZIKJOU_eMap.js is exported
# baseBIFKEI.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   1.91359e+11
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        2.31763e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             3.29445e+11
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   1.91359e+11
# ABEXUC_clean    ['H', 'C', 'N']                              2.87697e+11
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         2.31763e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        2.31763e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   1.91359e+11
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   1.91359e+11
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  1.91359e+11
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       2.31763e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   1.91359e+11
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  1.91359e+11
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        2.31763e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.91359e+11
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             3.29445e+11
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   1.91359e+11
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        2.31763e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.91359e+11
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   1.91359e+11
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        2.31763e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  1.91359e+11
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.91359e+11
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   1.91359e+11
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        2.31763e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              3.29445e+11
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        2.31763e+11
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        2.31763e+11
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.91359e+11
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        2.31763e+11
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              3.29445e+11
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   1.91359e+11
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.91359e+11
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.91359e+11
# CEKHIL.js is exported
# CEKHIL+CEKHIL_eMap.js is exported
# baseCEKHIL.js is exported
# COF-300.js is exported
# CEKHIL+COF-300_eMap.js is exported
# baseCEKHIL.js is exported
# COF-5.js is exported
# CEKHIL+COF-5_eMap.js is exported
# baseCEKHIL.js is exported
# CUYWUP.js is exported
# CEKHIL+CUYWUP_eMap.js is exported
# baseCEKHIL.js is exported
# DEPXIG.js is exported
# CEKHIL+DEPXIG_eMap.js is exported
# baseCEKHIL.js is exported
# GALBUS.js is exported
# CEKHIL+GALBUS_eMap.js is exported
# baseCEKHIL.js is exported
# GINLIA.js is exported
# CEKHIL+GINLIA_eMap.js is exported
# baseCEKHIL.js is exported
# GUNFAW01.js is exported
# CEKHIL+GUNFAW01_eMap.js is exported
# baseCEKHIL.js is exported
# HEGJUZ.js is exported
# CEKHIL+HEGJUZ_eMap.js is exported
# baseCEKHIL.js is exported
# HIGRIA.js is exported
# CEKHIL+HIGRIA_eMap.js is exported
# baseCEKHIL.js is exported
# HIHNUJ.js is exported
# CEKHIL+HIHNUJ_eMap.js is exported
# baseCEKHIL.js is exported
# IXAJUN.js is exported
# CEKHIL+IXAJUN_eMap.js is exported
# baseCEKHIL.js is exported
# IYIHUU.js is exported
# CEKHIL+IYIHUU_eMap.js is exported
# baseCEKHIL.js is exported
# JEJWOL.js is exported
# CEKHIL+JEJWOL_eMap.js is exported
# baseCEKHIL.js is exported
# LUYHAP.js is exported
# CEKHIL+LUYHAP_eMap.js is exported
# baseCEKHIL.js is exported
# MATVEJ.js is exported
# CEKHIL+MATVEJ_eMap.js is exported
# baseCEKHIL.js is exported
# MICPAQ.js is exported
# CEKHIL+MICPAQ_eMap.js is exported
# baseCEKHIL.js is exported
# MIL-88C-open.js is exported
# CEKHIL+MIL-88C-open_eMap.js is exported
# baseCEKHIL.js is exported
# NEDWIE.js is exported
# CEKHIL+NEDWIE_eMap.js is exported
# baseCEKHIL.js is exported
# NEHNEV.js is exported
# CEKHIL+NEHNEV_eMap.js is exported
# baseCEKHIL.js is exported
# OFODAP.js is exported
# CEKHIL+OFODAP_eMap.js is exported
# baseCEKHIL.js is exported
# RAVWAO.js is exported
# CEKHIL+RAVWAO_eMap.js is exported
# baseCEKHIL.js is exported
# RAXCOK.js is exported
# CEKHIL+RAXCOK_eMap.js is exported
# baseCEKHIL.js is exported
# UNIGEE.js is exported
# CEKHIL+UNIGEE_eMap.js is exported
# baseCEKHIL.js is exported
# VUSJUP.js is exported
# CEKHIL+VUSJUP_eMap.js is exported
# baseCEKHIL.js is exported
# XEBHOC.js is exported
# CEKHIL+XEBHOC_eMap.js is exported
# baseCEKHIL.js is exported
# XINFUW.js is exported
# CEKHIL+XINFUW_eMap.js is exported
# baseCEKHIL.js is exported
# XUGSEY.js is exported
# CEKHIL+XUGSEY_eMap.js is exported
# baseCEKHIL.js is exported
# YURJUR.js is exported
# CEKHIL+YURJUR_eMap.js is exported
# baseCEKHIL.js is exported
# ZIKJIO.js is exported
# CEKHIL+ZIKJIO_eMap.js is exported
# baseCEKHIL.js is exported
# ZIKJOU.js is exported
# CEKHIL+ZIKJOU_eMap.js is exported
# baseCEKHIL.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   1.12954e+12
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        1.3665e+12
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             1.93323e+12
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   1.12954e+12
# ABEXUC_clean    ['H', 'C', 'N']                              1.6924e+12
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         1.3665e+12
# ABEYIR          ['O', 'H', 'C', 'Cu']                        1.3665e+12
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   1.12954e+12
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   1.12954e+12
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  1.12954e+12
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       1.3665e+12
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   1.12954e+12
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  1.12954e+12
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        1.3665e+12
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.12954e+12
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             1.93323e+12
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   1.12954e+12
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        1.3665e+12
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.12954e+12
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   1.12954e+12
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        1.3665e+12
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  1.12954e+12
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.12954e+12
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   1.12954e+12
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        1.3665e+12
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              1.93323e+12
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        1.3665e+12
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        1.3665e+12
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.12954e+12
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        1.3665e+12
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              1.93323e+12
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   1.12954e+12
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.12954e+12
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.12954e+12
# COF-300.js is exported
# COF-300+COF-300_eMap.js is exported
# baseCOF-300.js is exported
# COF-5.js is exported
# COF-300+COF-5_eMap.js is exported
# baseCOF-300.js is exported
# CUYWUP.js is exported
# COF-300+CUYWUP_eMap.js is exported
# baseCOF-300.js is exported
# DEPXIG.js is exported
# COF-300+DEPXIG_eMap.js is exported
# baseCOF-300.js is exported
# GALBUS.js is exported
# COF-300+GALBUS_eMap.js is exported
# baseCOF-300.js is exported
# GINLIA.js is exported
# COF-300+GINLIA_eMap.js is exported
# baseCOF-300.js is exported
# GUNFAW01.js is exported
# COF-300+GUNFAW01_eMap.js is exported
# baseCOF-300.js is exported
# HEGJUZ.js is exported
# COF-300+HEGJUZ_eMap.js is exported
# baseCOF-300.js is exported
# HIGRIA.js is exported
# COF-300+HIGRIA_eMap.js is exported
# baseCOF-300.js is exported
# HIHNUJ.js is exported
# COF-300+HIHNUJ_eMap.js is exported
# baseCOF-300.js is exported
# IXAJUN.js is exported
# COF-300+IXAJUN_eMap.js is exported
# baseCOF-300.js is exported
# IYIHUU.js is exported
# COF-300+IYIHUU_eMap.js is exported
# baseCOF-300.js is exported
# JEJWOL.js is exported
# COF-300+JEJWOL_eMap.js is exported
# baseCOF-300.js is exported
# LUYHAP.js is exported
# COF-300+LUYHAP_eMap.js is exported
# baseCOF-300.js is exported
# MATVEJ.js is exported
# COF-300+MATVEJ_eMap.js is exported
# baseCOF-300.js is exported
# MICPAQ.js is exported
# COF-300+MICPAQ_eMap.js is exported
# baseCOF-300.js is exported
# MIL-88C-open.js is exported
# COF-300+MIL-88C-open_eMap.js is exported
# baseCOF-300.js is exported
# NEDWIE.js is exported
# COF-300+NEDWIE_eMap.js is exported
# baseCOF-300.js is exported
# NEHNEV.js is exported
# COF-300+NEHNEV_eMap.js is exported
# baseCOF-300.js is exported
# OFODAP.js is exported
# COF-300+OFODAP_eMap.js is exported
# baseCOF-300.js is exported
# RAVWAO.js is exported
# COF-300+RAVWAO_eMap.js is exported
# baseCOF-300.js is exported
# RAXCOK.js is exported
# COF-300+RAXCOK_eMap.js is exported
# baseCOF-300.js is exported
# UNIGEE.js is exported
# COF-300+UNIGEE_eMap.js is exported
# baseCOF-300.js is exported
# VUSJUP.js is exported
# COF-300+VUSJUP_eMap.js is exported
# baseCOF-300.js is exported
# XEBHOC.js is exported
# COF-300+XEBHOC_eMap.js is exported
# baseCOF-300.js is exported
# XINFUW.js is exported
# COF-300+XINFUW_eMap.js is exported
# baseCOF-300.js is exported
# XUGSEY.js is exported
# COF-300+XUGSEY_eMap.js is exported
# baseCOF-300.js is exported
# YURJUR.js is exported
# COF-300+YURJUR_eMap.js is exported
# baseCOF-300.js is exported
# ZIKJIO.js is exported
# COF-300+ZIKJIO_eMap.js is exported
# baseCOF-300.js is exported
# ZIKJOU.js is exported
# COF-300+ZIKJOU_eMap.js is exported
# baseCOF-300.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   4.83361e+11
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        5.83682e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             8.17866e+11
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   4.83361e+11
# ABEXUC_clean    ['H', 'C', 'N']                              7.1823e+11
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         5.83682e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        5.83682e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   4.83361e+11
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   4.83361e+11
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  4.83361e+11
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       5.83682e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   4.83361e+11
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  4.83361e+11
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        5.83682e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   4.83361e+11
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             8.17866e+11
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   4.83361e+11
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        5.83682e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   4.83361e+11
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   4.83361e+11
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        5.83682e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  4.83361e+11
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   4.83361e+11
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   4.83361e+11
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        5.83682e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              8.17866e+11
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        5.83682e+11
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        5.83682e+11
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   4.83361e+11
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        5.83682e+11
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              8.17866e+11
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   4.83361e+11
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   4.83361e+11
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   4.83361e+11
# COF-5.js is exported
# COF-5+COF-5_eMap.js is exported
# baseCOF-5.js is exported
# CUYWUP.js is exported
# COF-5+CUYWUP_eMap.js is exported
# baseCOF-5.js is exported
# DEPXIG.js is exported
# COF-5+DEPXIG_eMap.js is exported
# baseCOF-5.js is exported
# GALBUS.js is exported
# COF-5+GALBUS_eMap.js is exported
# baseCOF-5.js is exported
# GINLIA.js is exported
# COF-5+GINLIA_eMap.js is exported
# baseCOF-5.js is exported
# GUNFAW01.js is exported
# COF-5+GUNFAW01_eMap.js is exported
# baseCOF-5.js is exported
# HEGJUZ.js is exported
# COF-5+HEGJUZ_eMap.js is exported
# baseCOF-5.js is exported
# HIGRIA.js is exported
# COF-5+HIGRIA_eMap.js is exported
# baseCOF-5.js is exported
# HIHNUJ.js is exported
# COF-5+HIHNUJ_eMap.js is exported
# baseCOF-5.js is exported
# IXAJUN.js is exported
# COF-5+IXAJUN_eMap.js is exported
# baseCOF-5.js is exported
# IYIHUU.js is exported
# COF-5+IYIHUU_eMap.js is exported
# baseCOF-5.js is exported
# JEJWOL.js is exported
# COF-5+JEJWOL_eMap.js is exported
# baseCOF-5.js is exported
# LUYHAP.js is exported
# COF-5+LUYHAP_eMap.js is exported
# baseCOF-5.js is exported
# MATVEJ.js is exported
# COF-5+MATVEJ_eMap.js is exported
# baseCOF-5.js is exported
# MICPAQ.js is exported
# COF-5+MICPAQ_eMap.js is exported
# baseCOF-5.js is exported
# MIL-88C-open.js is exported
# COF-5+MIL-88C-open_eMap.js is exported
# baseCOF-5.js is exported
# NEDWIE.js is exported
# COF-5+NEDWIE_eMap.js is exported
# baseCOF-5.js is exported
# NEHNEV.js is exported
# COF-5+NEHNEV_eMap.js is exported
# baseCOF-5.js is exported
# OFODAP.js is exported
# COF-5+OFODAP_eMap.js is exported
# baseCOF-5.js is exported
# RAVWAO.js is exported
# COF-5+RAVWAO_eMap.js is exported
# baseCOF-5.js is exported
# RAXCOK.js is exported
# COF-5+RAXCOK_eMap.js is exported
# baseCOF-5.js is exported
# UNIGEE.js is exported
# COF-5+UNIGEE_eMap.js is exported
# baseCOF-5.js is exported
# VUSJUP.js is exported
# COF-5+VUSJUP_eMap.js is exported
# baseCOF-5.js is exported
# XEBHOC.js is exported
# COF-5+XEBHOC_eMap.js is exported
# baseCOF-5.js is exported
# XINFUW.js is exported
# COF-5+XINFUW_eMap.js is exported
# baseCOF-5.js is exported
# XUGSEY.js is exported
# COF-5+XUGSEY_eMap.js is exported
# baseCOF-5.js is exported
# YURJUR.js is exported
# COF-5+YURJUR_eMap.js is exported
# baseCOF-5.js is exported
# ZIKJIO.js is exported
# COF-5+ZIKJIO_eMap.js is exported
# baseCOF-5.js is exported
# ZIKJOU.js is exported
# COF-5+ZIKJOU_eMap.js is exported
# baseCOF-5.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   1.28728e+11
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        1.55966e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             2.27804e+11
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   1.28728e+11
# ABEXUC_clean    ['H', 'C', 'N']                              1.94091e+11
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         1.55966e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        1.55966e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   1.28728e+11
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   1.28728e+11
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  1.28728e+11
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       1.55966e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   1.28728e+11
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  1.28728e+11
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        1.55966e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.28728e+11
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             2.27804e+11
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   1.28728e+11
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        1.55966e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.28728e+11
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   1.28728e+11
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        1.55966e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  1.28728e+11
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.28728e+11
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   1.28728e+11
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        1.55966e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              2.27804e+11
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        1.55966e+11
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        1.55966e+11
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.28728e+11
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        1.55966e+11
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              2.27804e+11
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   1.28728e+11
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.28728e+11
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.28728e+11
# CUYWUP.js is exported
# CUYWUP+CUYWUP_eMap.js is exported
# baseCUYWUP.js is exported
# DEPXIG.js is exported
# CUYWUP+DEPXIG_eMap.js is exported
# baseCUYWUP.js is exported
# GALBUS.js is exported
# CUYWUP+GALBUS_eMap.js is exported
# baseCUYWUP.js is exported
# GINLIA.js is exported
# CUYWUP+GINLIA_eMap.js is exported
# baseCUYWUP.js is exported
# GUNFAW01.js is exported
# CUYWUP+GUNFAW01_eMap.js is exported
# baseCUYWUP.js is exported
# HEGJUZ.js is exported
# CUYWUP+HEGJUZ_eMap.js is exported
# baseCUYWUP.js is exported
# HIGRIA.js is exported
# CUYWUP+HIGRIA_eMap.js is exported
# baseCUYWUP.js is exported
# HIHNUJ.js is exported
# CUYWUP+HIHNUJ_eMap.js is exported
# baseCUYWUP.js is exported
# IXAJUN.js is exported
# CUYWUP+IXAJUN_eMap.js is exported
# baseCUYWUP.js is exported
# IYIHUU.js is exported
# CUYWUP+IYIHUU_eMap.js is exported
# baseCUYWUP.js is exported
# JEJWOL.js is exported
# CUYWUP+JEJWOL_eMap.js is exported
# baseCUYWUP.js is exported
# LUYHAP.js is exported
# CUYWUP+LUYHAP_eMap.js is exported
# baseCUYWUP.js is exported
# MATVEJ.js is exported
# CUYWUP+MATVEJ_eMap.js is exported
# baseCUYWUP.js is exported
# MICPAQ.js is exported
# CUYWUP+MICPAQ_eMap.js is exported
# baseCUYWUP.js is exported
# MIL-88C-open.js is exported
# CUYWUP+MIL-88C-open_eMap.js is exported
# baseCUYWUP.js is exported
# NEDWIE.js is exported
# CUYWUP+NEDWIE_eMap.js is exported
# baseCUYWUP.js is exported
# NEHNEV.js is exported
# CUYWUP+NEHNEV_eMap.js is exported
# baseCUYWUP.js is exported
# OFODAP.js is exported
# CUYWUP+OFODAP_eMap.js is exported
# baseCUYWUP.js is exported
# RAVWAO.js is exported
# CUYWUP+RAVWAO_eMap.js is exported
# baseCUYWUP.js is exported
# RAXCOK.js is exported
# CUYWUP+RAXCOK_eMap.js is exported
# baseCUYWUP.js is exported
# UNIGEE.js is exported
# CUYWUP+UNIGEE_eMap.js is exported
# baseCUYWUP.js is exported
# VUSJUP.js is exported
# CUYWUP+VUSJUP_eMap.js is exported
# baseCUYWUP.js is exported
# XEBHOC.js is exported
# CUYWUP+XEBHOC_eMap.js is exported
# baseCUYWUP.js is exported
# XINFUW.js is exported
# CUYWUP+XINFUW_eMap.js is exported
# baseCUYWUP.js is exported
# XUGSEY.js is exported
# CUYWUP+XUGSEY_eMap.js is exported
# baseCUYWUP.js is exported
# YURJUR.js is exported
# CUYWUP+YURJUR_eMap.js is exported
# baseCUYWUP.js is exported
# ZIKJIO.js is exported
# CUYWUP+ZIKJIO_eMap.js is exported
# baseCUYWUP.js is exported
# ZIKJOU.js is exported
# CUYWUP+ZIKJOU_eMap.js is exported
# baseCUYWUP.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   2.63686e+11
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        3.19515e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             4.56954e+11
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   2.63686e+11
# ABEXUC_clean    ['H', 'C', 'N']                              3.97608e+11
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         3.19515e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        3.19515e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   2.63686e+11
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   2.63686e+11
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  2.63686e+11
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       3.19515e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   2.63686e+11
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  2.63686e+11
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        3.19515e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   2.63686e+11
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             4.56954e+11
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   2.63686e+11
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        3.19515e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   2.63686e+11
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   2.63686e+11
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        3.19515e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  2.63686e+11
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   2.63686e+11
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   2.63686e+11
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        3.19515e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              4.56954e+11
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        3.19515e+11
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        3.19515e+11
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   2.63686e+11
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        3.19515e+11
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              4.56954e+11
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   2.63686e+11
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   2.63686e+11
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   2.63686e+11
# DEPXIG.js is exported
# DEPXIG+DEPXIG_eMap.js is exported
# baseDEPXIG.js is exported
# GALBUS.js is exported
# DEPXIG+GALBUS_eMap.js is exported
# baseDEPXIG.js is exported
# GINLIA.js is exported
# DEPXIG+GINLIA_eMap.js is exported
# baseDEPXIG.js is exported
# GUNFAW01.js is exported
# DEPXIG+GUNFAW01_eMap.js is exported
# baseDEPXIG.js is exported
# HEGJUZ.js is exported
# DEPXIG+HEGJUZ_eMap.js is exported
# baseDEPXIG.js is exported
# HIGRIA.js is exported
# DEPXIG+HIGRIA_eMap.js is exported
# baseDEPXIG.js is exported
# HIHNUJ.js is exported
# DEPXIG+HIHNUJ_eMap.js is exported
# baseDEPXIG.js is exported
# IXAJUN.js is exported
# DEPXIG+IXAJUN_eMap.js is exported
# baseDEPXIG.js is exported
# IYIHUU.js is exported
# DEPXIG+IYIHUU_eMap.js is exported
# baseDEPXIG.js is exported
# JEJWOL.js is exported
# DEPXIG+JEJWOL_eMap.js is exported
# baseDEPXIG.js is exported
# LUYHAP.js is exported
# DEPXIG+LUYHAP_eMap.js is exported
# baseDEPXIG.js is exported
# MATVEJ.js is exported
# DEPXIG+MATVEJ_eMap.js is exported
# baseDEPXIG.js is exported
# MICPAQ.js is exported
# DEPXIG+MICPAQ_eMap.js is exported
# baseDEPXIG.js is exported
# MIL-88C-open.js is exported
# DEPXIG+MIL-88C-open_eMap.js is exported
# baseDEPXIG.js is exported
# NEDWIE.js is exported
# DEPXIG+NEDWIE_eMap.js is exported
# baseDEPXIG.js is exported
# NEHNEV.js is exported
# DEPXIG+NEHNEV_eMap.js is exported
# baseDEPXIG.js is exported
# OFODAP.js is exported
# DEPXIG+OFODAP_eMap.js is exported
# baseDEPXIG.js is exported
# RAVWAO.js is exported
# DEPXIG+RAVWAO_eMap.js is exported
# baseDEPXIG.js is exported
# RAXCOK.js is exported
# DEPXIG+RAXCOK_eMap.js is exported
# baseDEPXIG.js is exported
# UNIGEE.js is exported
# DEPXIG+UNIGEE_eMap.js is exported
# baseDEPXIG.js is exported
# VUSJUP.js is exported
# DEPXIG+VUSJUP_eMap.js is exported
# baseDEPXIG.js is exported
# XEBHOC.js is exported
# DEPXIG+XEBHOC_eMap.js is exported
# baseDEPXIG.js is exported
# XINFUW.js is exported
# DEPXIG+XINFUW_eMap.js is exported
# baseDEPXIG.js is exported
# XUGSEY.js is exported
# DEPXIG+XUGSEY_eMap.js is exported
# baseDEPXIG.js is exported
# YURJUR.js is exported
# DEPXIG+YURJUR_eMap.js is exported
# baseDEPXIG.js is exported
# ZIKJIO.js is exported
# DEPXIG+ZIKJIO_eMap.js is exported
# baseDEPXIG.js is exported
# ZIKJOU.js is exported
# DEPXIG+ZIKJOU_eMap.js is exported
# baseDEPXIG.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   8.40369e+10
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        1.01788e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             1.45075e+11
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   8.40369e+10
# ABEXUC_clean    ['H', 'C', 'N']                              1.26327e+11
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         1.01788e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        1.01788e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   8.40369e+10
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   8.40369e+10
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  8.40369e+10
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       1.01788e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   8.40369e+10
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  8.40369e+10
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        1.01788e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   8.40369e+10
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             1.45075e+11
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   8.40369e+10
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        1.01788e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   8.40369e+10
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   8.40369e+10
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        1.01788e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  8.40369e+10
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   8.40369e+10
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   8.40369e+10
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        1.01788e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              1.45075e+11
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        1.01788e+11
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        1.01788e+11
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   8.40369e+10
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        1.01788e+11
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              1.45075e+11
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   8.40369e+10
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   8.40369e+10
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   8.40369e+10
# GALBUS.js is exported
# GALBUS+GALBUS_eMap.js is exported
# baseGALBUS.js is exported
# GINLIA.js is exported
# GALBUS+GINLIA_eMap.js is exported
# baseGALBUS.js is exported
# GUNFAW01.js is exported
# GALBUS+GUNFAW01_eMap.js is exported
# baseGALBUS.js is exported
# HEGJUZ.js is exported
# GALBUS+HEGJUZ_eMap.js is exported
# baseGALBUS.js is exported
# HIGRIA.js is exported
# GALBUS+HIGRIA_eMap.js is exported
# baseGALBUS.js is exported
# HIHNUJ.js is exported
# GALBUS+HIHNUJ_eMap.js is exported
# baseGALBUS.js is exported
# IXAJUN.js is exported
# GALBUS+IXAJUN_eMap.js is exported
# baseGALBUS.js is exported
# IYIHUU.js is exported
# GALBUS+IYIHUU_eMap.js is exported
# baseGALBUS.js is exported
# JEJWOL.js is exported
# GALBUS+JEJWOL_eMap.js is exported
# baseGALBUS.js is exported
# LUYHAP.js is exported
# GALBUS+LUYHAP_eMap.js is exported
# baseGALBUS.js is exported
# MATVEJ.js is exported
# GALBUS+MATVEJ_eMap.js is exported
# baseGALBUS.js is exported
# MICPAQ.js is exported
# GALBUS+MICPAQ_eMap.js is exported
# baseGALBUS.js is exported
# MIL-88C-open.js is exported
# GALBUS+MIL-88C-open_eMap.js is exported
# baseGALBUS.js is exported
# NEDWIE.js is exported
# GALBUS+NEDWIE_eMap.js is exported
# baseGALBUS.js is exported
# NEHNEV.js is exported
# GALBUS+NEHNEV_eMap.js is exported
# baseGALBUS.js is exported
# OFODAP.js is exported
# GALBUS+OFODAP_eMap.js is exported
# baseGALBUS.js is exported
# RAVWAO.js is exported
# GALBUS+RAVWAO_eMap.js is exported
# baseGALBUS.js is exported
# RAXCOK.js is exported
# GALBUS+RAXCOK_eMap.js is exported
# baseGALBUS.js is exported
# UNIGEE.js is exported
# GALBUS+UNIGEE_eMap.js is exported
# baseGALBUS.js is exported
# VUSJUP.js is exported
# GALBUS+VUSJUP_eMap.js is exported
# baseGALBUS.js is exported
# XEBHOC.js is exported
# GALBUS+XEBHOC_eMap.js is exported
# baseGALBUS.js is exported
# XINFUW.js is exported
# GALBUS+XINFUW_eMap.js is exported
# baseGALBUS.js is exported
# XUGSEY.js is exported
# GALBUS+XUGSEY_eMap.js is exported
# baseGALBUS.js is exported
# YURJUR.js is exported
# GALBUS+YURJUR_eMap.js is exported
# baseGALBUS.js is exported
# ZIKJIO.js is exported
# GALBUS+ZIKJIO_eMap.js is exported
# baseGALBUS.js is exported
# ZIKJOU.js is exported
# GALBUS+ZIKJOU_eMap.js is exported
# baseGALBUS.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   7.27275e+11
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        8.80462e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             1.24774e+12
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   7.27275e+11
# ABEXUC_clean    ['H', 'C', 'N']                              1.09269e+12
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         8.80462e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        8.80462e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   7.27275e+11
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   7.27275e+11
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  7.27275e+11
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       8.80462e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   7.27275e+11
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  7.27275e+11
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        8.80462e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.27275e+11
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             1.24774e+12
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   7.27275e+11
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        8.80462e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   7.27275e+11
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   7.27275e+11
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        8.80462e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  7.27275e+11
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   7.27275e+11
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   7.27275e+11
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        8.80462e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              1.24774e+12
# ...
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   2.42277e+12
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        2.93873e+12
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  2.42277e+12
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   2.42277e+12
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   2.42277e+12
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        2.93873e+12
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              4.23689e+12
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        2.93873e+12
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        2.93873e+12
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   2.42277e+12
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        2.93873e+12
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              4.23689e+12
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   2.42277e+12
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   2.42277e+12
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   2.42277e+12
# XEBHOC.js is exported
# XEBHOC+XEBHOC_eMap.js is exported
# baseXEBHOC.js is exported
# XINFUW.js is exported
# XEBHOC+XINFUW_eMap.js is exported
# baseXEBHOC.js is exported
# XUGSEY.js is exported
# XEBHOC+XUGSEY_eMap.js is exported
# baseXEBHOC.js is exported
# YURJUR.js is exported
# XEBHOC+YURJUR_eMap.js is exported
# baseXEBHOC.js is exported
# ZIKJIO.js is exported
# XEBHOC+ZIKJIO_eMap.js is exported
# baseXEBHOC.js is exported
# ZIKJOU.js is exported
# XEBHOC+ZIKJOU_eMap.js is exported
# baseXEBHOC.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   1.60442e+11
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        1.94677e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             2.77913e+11
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   1.60442e+11
# ABEXUC_clean    ['H', 'C', 'N']                              2.43711e+11
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         1.94677e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        1.94677e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   1.60442e+11
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   1.60442e+11
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  1.60442e+11
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       1.94677e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   1.60442e+11
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  1.60442e+11
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        1.94677e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.60442e+11
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             2.77913e+11
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   1.60442e+11
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        1.94677e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.60442e+11
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   1.60442e+11
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        1.94677e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  1.60442e+11
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.60442e+11
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   1.60442e+11
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        1.94677e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              2.77913e+11
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        1.94677e+11
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        1.94677e+11
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.60442e+11
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        1.94677e+11
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              2.77913e+11
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   1.60442e+11
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.60442e+11
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.60442e+11
# XINFUW.js is exported
# XINFUW+XINFUW_eMap.js is exported
# baseXINFUW.js is exported
# XUGSEY.js is exported
# XINFUW+XUGSEY_eMap.js is exported
# baseXINFUW.js is exported
# YURJUR.js is exported
# XINFUW+YURJUR_eMap.js is exported
# baseXINFUW.js is exported
# ZIKJIO.js is exported
# XINFUW+ZIKJIO_eMap.js is exported
# baseXINFUW.js is exported
# ZIKJOU.js is exported
# XINFUW+ZIKJOU_eMap.js is exported
# baseXINFUW.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   1.20111e+12
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        1.45289e+12
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             2.05502e+12
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   1.20111e+12
# ABEXUC_clean    ['H', 'C', 'N']                              1.80024e+12
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         1.45289e+12
# ABEYIR          ['O', 'H', 'C', 'Cu']                        1.45289e+12
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   1.20111e+12
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   1.20111e+12
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  1.20111e+12
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       1.45289e+12
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   1.20111e+12
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  1.20111e+12
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        1.45289e+12
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.20111e+12
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             2.05502e+12
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   1.20111e+12
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        1.45289e+12
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.20111e+12
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   1.20111e+12
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        1.45289e+12
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  1.20111e+12
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.20111e+12
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   1.20111e+12
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        1.45289e+12
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              2.05502e+12
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        1.45289e+12
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        1.45289e+12
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.20111e+12
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        1.45289e+12
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              2.05502e+12
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   1.20111e+12
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.20111e+12
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.20111e+12
# XUGSEY.js is exported
# XUGSEY+XUGSEY_eMap.js is exported
# baseXUGSEY.js is exported
# YURJUR.js is exported
# XUGSEY+YURJUR_eMap.js is exported
# baseXUGSEY.js is exported
# ZIKJIO.js is exported
# XUGSEY+ZIKJIO_eMap.js is exported
# baseXUGSEY.js is exported
# ZIKJOU.js is exported
# XUGSEY+ZIKJOU_eMap.js is exported
# baseXUGSEY.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   7.12109e+10
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        8.61543e+10
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             1.234e+11
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   7.12109e+10
# ABEXUC_clean    ['H', 'C', 'N']                              1.06922e+11
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         8.61543e+10
# ABEYIR          ['O', 'H', 'C', 'Cu']                        8.61543e+10
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   7.12109e+10
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   7.12109e+10
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  7.12109e+10
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       8.61543e+10
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   7.12109e+10
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  7.12109e+10
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        8.61543e+10
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.12109e+10
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             1.234e+11
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   7.12109e+10
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        8.61543e+10
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   7.12109e+10
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   7.12109e+10
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        8.61543e+10
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  7.12109e+10
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   7.12109e+10
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   7.12109e+10
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        8.61543e+10
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              1.234e+11
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        8.61543e+10
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        8.61543e+10
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.12109e+10
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        8.61543e+10
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              1.234e+11
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   7.12109e+10
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.12109e+10
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   7.12109e+10
# YURJUR.js is exported
# YURJUR+YURJUR_eMap.js is exported
# baseYURJUR.js is exported
# ZIKJIO.js is exported
# YURJUR+ZIKJIO_eMap.js is exported
# baseYURJUR.js is exported
# ZIKJOU.js is exported
# YURJUR+ZIKJOU_eMap.js is exported
# baseYURJUR.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   8.08617e+11
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        9.78744e+11
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             1.39042e+12
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   8.08617e+11
# ABEXUC_clean    ['H', 'C', 'N']                              1.21243e+12
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         9.78744e+11
# ABEYIR          ['O', 'H', 'C', 'Cu']                        9.78744e+11
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   8.08617e+11
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   8.08617e+11
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  8.08617e+11
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       9.78744e+11
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   8.08617e+11
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  8.08617e+11
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        9.78744e+11
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   8.08617e+11
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             1.39042e+12
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   8.08617e+11
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        9.78744e+11
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   8.08617e+11
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   8.08617e+11
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        9.78744e+11
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  8.08617e+11
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   8.08617e+11
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   8.08617e+11
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        9.78744e+11
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              1.39042e+12
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        9.78744e+11
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        9.78744e+11
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   8.08617e+11
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        9.78744e+11
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              1.39042e+12
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   8.08617e+11
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   8.08617e+11
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   8.08617e+11
# ZIKJIO.js is exported
# ZIKJIO+ZIKJIO_eMap.js is exported
# baseZIKJIO.js is exported
# ZIKJOU.js is exported
# ZIKJIO+ZIKJOU_eMap.js is exported
# baseZIKJIO.js is exported
# MOF Name        Atoms                               Average Energy Limit
# --------------  --------------------------------  ----------------------
# ABAVIJ_clean    ['O', 'H', 'C', 'N', 'Co']                   1.25338e+12
# ABAVOP_clean    ['Zn', 'H', 'C', 'N']                        1.52016e+12
# ABEXIQ_clean    ['Cl', 'O', 'H', 'C', 'N', 'Cu']             2.18351e+12
# ABEXOW_clean    ['O', 'H', 'C', 'N', 'Co']                   1.25338e+12
# ABEXUC_clean    ['H', 'C', 'N']                              1.89371e+12
# ABEYAJ_clean    ['O', 'H', 'C', 'B']                         1.52016e+12
# ABEYIR          ['O', 'H', 'C', 'Cu']                        1.52016e+12
# ABIYIV          ['O', 'Mn', 'H', 'C', 'N']                   1.25338e+12
# ABUWOJ_clean    ['O', 'H', 'C', 'N', 'Ni']                   1.25338e+12
# ACAKUM          ['Cl', 'O', 'Zn', 'H', 'C']                  1.25338e+12
# ACALIB_clean    ['O', 'Mn', 'C', 'Cr']                       1.52016e+12
# ACODED          ['O', 'Zn', 'H', 'C', 'N']                   1.25338e+12
# ACOLIP_clean    ['Zn', 'H', 'C', 'N', 'Co']                  1.25338e+12
# ACOLUB_clean    ['O', 'H', 'C', 'In']                        1.52016e+12
# ACUBAB_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.25338e+12
# ACUTOI_clean    ['O', 'Zn', 'Br', 'H', 'C', 'N']             2.18351e+12
# ADABAK          ['O', 'H', 'C', 'Nd', 'N']                   1.25338e+12
# ADABAK01_clean  ['O', 'H', 'C', 'Cu']                        1.52016e+12
# ADABIS_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.25338e+12
# ADABUE_clean    ['Cd', 'H', 'F', 'C', 'N']                   1.25338e+12
# ADAXEK_clean    ['Fe', 'O', 'H', 'C']                        1.52016e+12
# ADEGIA_clean    ['O', 'Mn', 'H', 'C', 'Ni']                  1.25338e+12
# ADIQEL_clean    ['O', 'Zn', 'H', 'C', 'N']                   1.25338e+12
# ADOBAX          ['O', 'Cd', 'H', 'C', 'N']                   1.25338e+12
# ADOBOL_clean    ['O', 'H', 'C', 'Mg']                        1.52016e+12
# AFITIT_clean    ['O', 'Zn', 'S', 'H', 'C', 'N']              2.18351e+12
# AFIXAO_clean    ['O', 'Zn', 'H', 'C']                        1.52016e+12
# AFOQUI_clean    ['O', 'Zn', 'H', 'C']                        1.52016e+12
# AFOTUL_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.25338e+12
# AFOVAT_clean    ['O', 'Zn', 'H', 'C']                        1.52016e+12
# AFOVIB_clean    ['O', 'Zn', 'H', 'F', 'C', 'N']              2.18351e+12
# AFOVOH_clean    ['O', 'Ce', 'S', 'H', 'C']                   1.25338e+12
# AFOYOK_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.25338e+12
# AFUPEX_clean    ['O', 'H', 'C', 'N', 'Cu']                   1.25338e+12
# ZIKJOU.js is exported
# ZIKJOU+ZIKJOU_eMap.js is exported
# baseZIKJOU.js is exported

# %%
import math
coor = [-25, 21, 34]
UCsize = [6, 16, 8]
UCangle = [90, 90, 90]


fracCoor = car2frac(coor, UCsize, UCangle, ucv)
print(fracCoor)
pbcCoor = fracPBC(fracCoor)
print(pbcCoor)
# Out:
# [-4.166666666666666, 1.3124999999999998, 4.25]
# [0.8333333333333339, 0.3124999999999998, 0.25]
